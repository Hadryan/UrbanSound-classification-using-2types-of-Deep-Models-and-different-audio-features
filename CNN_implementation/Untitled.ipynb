# %%
import IPython.display as ipd
import librosa
import librosa.display
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

filename="C:/Users/User/Desktop/Augmented Sample/Augmentation/7066-6-1-0/7066-6-1-0 Original.wav"

# %%
plt.figure(figsize=(12,4))

# %%
data, sample_rate=librosa.load(filename)
librosa.display.waveplot(data , sr=sample_rate)

# %%
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mfccs=librosa.feature.mfcc(y=data , sr=sample_rate , n_mfcc=1)

# %%
librosa.display.specshow(mfccs, sr=sample_rate , x_axis='time')

# %%
filename2='C:/Users/User/Desktop/Augmented Sample/Augmentation/7066-6-1-0/7066-6-1-0 Noise Added.wav'

# %%
plt.figure(figsize=(12,4))
data, sample_rate=(librosa.load(filename))
librosa.display.waveplot(data , sr=sample_rate)

# %%
mfccs=librosa.feature.mfcc(data , sr=sample_rate)

# %%
np.asfortranarray(librosa.display.waveplot(mfccs, sr=sample_rate, x_axis='time'))
# Out:
# ---------------------------------------------------------------------------
# ParameterError                            Traceback (most recent call last)
# <ipython-input-53-e3e062604bbd> in <module>
# ----> 1 np.asfortranarray(librosa.display.waveplot(mfccs, sr=sample_rate, x_axis='time'))
#
# ~\Anaconda3\lib\site-packages\librosa\display.py in waveplot(y, sr, max_points, x_axis, offset, max_sr, ax, **kwargs)
#     464     '''
#     465
# --> 466     util.valid_audio(y, mono=False)
#     467
#     468     if not (isinstance(max_sr, int) and max_sr > 0):
#
# ~\Anaconda3\lib\site-packages\librosa\util\utils.py in valid_audio(y, mono)
#     276
#     277     if not y.flags["F_CONTIGUOUS"]:
# --> 278         raise ParameterError('Audio buffer is not Fortran-contiguous. '
#     279             'Use numpy.asfortranarray to ensure Fortran contiguity.')
#     280
#
# ParameterError: Audio buffer is not Fortran-contiguous. Use numpy.asfortranarray to ensure Fortran contiguity.
