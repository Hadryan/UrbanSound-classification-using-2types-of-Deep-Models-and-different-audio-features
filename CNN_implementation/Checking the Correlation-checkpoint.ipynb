# %% [markdown]
# # Original Clip

# %%
import IPython.display as ipd
import librosa
import librosa.display
# %matplotlib inline 
import matplotlib.pyplot as plt
filename='E:/Thesis/Dataset/Sample Augmented Sound clips/Augmentation/7066-6-1-0/7066-6-1-0 Original.wav'
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y, sr =librosa.load(filename)
plt.figure(figsize=(10,4))
plt.plot(y)
plt.xlabel('Time')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
y, sr =librosa.load(filename)

# %%
mfccs=librosa.feature.mfcc(y , sr)
plt.figure(figsize=(10,4))
librosa.display.specshow(mfccs , x_axis='time')
plt.ylabel('Coefficient of MFCC')
# Out:
# Text(0, 0.5, 'Coefficient of MFCC')

# %%
print(mfccs)
# Out:
# [[ -80.984055     8.70114     16.264788  ... -503.37335   -506.83
#   -513.6395   ]
#  [  51.382195    43.956055    42.11299   ...   65.29085     60.614803
#     52.39409  ]
#  [  30.297089    31.818771    31.246727  ...   42.94072     38.845818
#     34.115273 ]
#  ...
#  [  11.699739    13.225176    13.693998  ...    9.371195     7.8398294
#      9.287584 ]
#  [   3.7669013    2.175344     1.822629  ...    6.749155     6.960594
#     10.50337  ]
#  [   4.597885     5.471058     4.0775757 ...    3.6464949    5.3546743
#     10.037903 ]]

# %% [markdown]
# # Augmented Data

# %% [markdown]
# ## Noise Added to Gunshot V2

# %%
filename2='E:/Thesis/Dataset/Sample Augmented Sound clips/Augmentation/7066-6-1-0/7066-6-1-0 Noise Added v2.wav'
ipd.Audio(filename2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(10,4))
y, sr =librosa.load(filename2)
plt.plot(y)
plt.xlabel('Time')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
mfccs=librosa.feature.mfcc(y, sr)
plt.figure(figsize=(10,4))
librosa.display.specshow(mfccs, x_axis='time')
plt.ylabel('Coefficient of MFCC')
# Out:
# Text(0, 0.5, 'Coefficient of MFCC')

# %%
print(mfccs)
# Out:
# [[-2.5712254e+01  2.5654591e+01  2.7077595e+01 ... -5.0640860e+02
#   -5.0984512e+02 -5.1721509e+02]
#  [ 1.0518872e+02  7.0058212e+01  6.4387100e+01 ...  7.5342148e+01
#    7.0683472e+01  6.1889584e+01]
#  [ 3.5381233e+01  3.8358978e+01  4.1125282e+01 ...  4.6166824e+01
#    4.2061657e+01  3.7474701e+01]
#  ...
#  [-1.0718946e+00  5.8758011e+00  1.1438069e+01 ...  9.2226353e+00
#    7.9000702e+00  8.1925850e+00]
#  [-2.8767538e-01 -2.0012414e+00 -2.1854818e+00 ...  6.8362503e+00
#    6.7894726e+00  9.5249262e+00]
#  [ 1.2562057e+00  3.5720582e+00 -6.8021774e-02 ...  3.9670086e+00
#    5.2967892e+00  1.0693515e+01]]

# %% [markdown]
# ## Noise Added and pitch up to GunShot

# %%
filename3='E:/Thesis/Dataset/Sample Augmented Sound clips/Augmentation/7066-6-1-0/7066-6-1-0 Noise Added + Pitch Up v2.wav'
ipd.Audio(filename)
#y, sr =librosa.load(filename3)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y, sr =librosa.load(filename3)
plt.figure(figsize=(10,4))
plt.plot(y)
plt.xlabel('Time')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
mfccs=librosa.feature.mfcc(y , sr)
plt.figure(figsize=(10,4))
librosa.display.specshow(mfccs, x_axis='time')
plt.ylabel('Coefficient of MFCC')
# Out:
# Text(0, 0.5, 'Coefficient of MFCC')

# %%
print(mfccs)
# Out:
# [[ -25.995852     13.248671      7.9685125  ... -517.52734
#   -521.05707    -534.0801    ]
#  [ 102.04479      77.27359      71.37482    ...   67.88913
#     64.47061      49.938583  ]
#  [  30.007214     38.33623      42.63996    ...   37.9047
#     38.203247     32.805332  ]
#  ...
#  [   0.89501417    4.1121063    10.53244    ...    3.9383936
#      2.7408671     8.426453  ]
#  [   5.235384     -0.6117371    -3.5253062  ...    1.9967968
#      0.57834387    7.132455  ]
#  [   8.350074      4.3183823    -3.159623   ...    1.208836
#      0.83245176    4.6525183 ]]
