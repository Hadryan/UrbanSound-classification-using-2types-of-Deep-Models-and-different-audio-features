# %%
import os
import sys
from os import listdir
from os.path import isfile, join
import IPython.display as ipd
import librosa 
import librosa.display
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from scipy.io import wavfile as wav
import numpy as np
from timeit import default_timer as timer

# %%
X=np.array([93,56,43,21,45,64,70,80,90,97])
Y=np.array([95,69,80,34,70,24,35,43,35,24])
print(X)
# Out:
# [93 56 43 21 45 64 70 80 90 97]

# %%
labels = ['Air Conditioner','Car Horn','Children Playing','Dog bark','Drilling','Engine Idling','Gun Shot','Jackhammer','Siren','Street Music']

# %%
plt.figure(figsize=(10,6))
plt.plot(X, 'o-' , markersize=15, label='LSTM')
plt.plot(Y, 'o-' ,markersize=15, label='CNN' )
index=np.arange(len(labels))
plt.xticks(index, labels, rotation=90)
plt.legend()
plt.show()
